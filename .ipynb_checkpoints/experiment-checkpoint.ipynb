# %%
import torch
import torch.nn as nn

x = torch.rand(1, 3, 52, 52)
conv = nn.Conv2d(3, 256, kernel_size=1,stride=1,padding=1)
y = conv(x)
print(y.shape)
# Out:
# torch.Size([1, 256, 54, 54])

# %%
import json
with open("/scr1/li108/data/annotations/person_keypoints_train2017.json") as f:
    y = json.load(f)

# %%
y
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
y['annotations'][0].keys()
# Out:
# dict_keys(['segmentation', 'num_keypoints', 'area', 'iscrowd', 'keypoints', 'image_id', 'bbox', 'category_id', 'id'])

# %%
#y['annotations'][0]['segmentation'][0]

# %%
# get coco dataset 
with open("/scr1/li108/data/annotations/instances_train2017.json") as f:
    z = json.load(f)

# %%
z.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
z['annotations'][0]
# Out:
# {'segmentation': [[239.97,
#    260.24,
#    222.04,
#    270.49,
#    199.84,
#    253.41,
#    213.5,
#    227.79,
#    259.62,
#    200.46,
#    274.13,
#    202.17,
#    277.55,
#    210.71,
#    249.37,
#    253.41,
#    237.41,
#    264.51,
#    242.54,
#    261.95,
#    228.87,
#    271.34]],
#  'area': 2765.1486500000005,
#  'iscrowd': 0,
#  'image_id': 558840,
#  'bbox': [199.84, 200.46, 77.71, 70.88],
#  'category_id': 58,
#  'id': 156}

# %%
import torchvision.datasets as datasets
import os.path as osp
data_dir = '/scr1/li108/data'
d = datasets.CocoDetection(root=osp.join(data_dir,'coco_train_2017'),
                          annFile=osp.join(data_dir, 'annotations',
                                          'instances_train2017.json')
                          )
# Out:
# loading annotations into memory...
# Done (t=11.30s)
# creating index...
# index created!
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7F0190038278>

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np


img, taget = d[0]

img_ = np.array(img, dtype=np.uint8)
print(img_.shape)
fig, ax = plt.subplots(1)
ax.imshow(img_)


for a in [taget[0]]:
    x,y,x_,y_ = a['bbox']
    print(a['bbox'])
    rect = patches.Rectangle((x,y),x_,y_,linewidth=1,
                             edgecolor='r', facecolor='none')
    ax.add_patch(rect)

plt.show()
# Out:
# (360, 640, 3)
# [359.17, 146.17, 112.45, 213.57]

# %%
import torch

def get_center_of_bbox(target):
    obj_center = {}
    for obj in target:
        bbox = obj['bbox']
        x, y, w, h = bbox
        center_x = x + (w//2)
        center_y = y + (h//2)
        
        gx_idx = center_x // grid_w
        gy_idx = center_y // grid_h
        
        gx_idx,gy_
        
        
    return

def partition_to_grid(img_dim, grid_dim):
    '''
        returns a list of grid info
        each grid info contains it left top coordiate
        width and height
    '''
    x, y = grid_dim
    w, h = img_dim
    grid_w = w // x
    grid_h = h // y
    return


def compute_iou(rec1, rec2):
    '''
    Given two rectangles rec1 and rec2 
    computes its iou
    
    Args:
        rec1: tensor of shape B x 4
        First dim is the batch size;
        Second dim is the top-left coordinate,
        width and height
    '''
    # get coordinate of vertices of rec1 and rec2
    # in the order top-left, top-right, bottom-left, bottom-right
    # write it as a tensor of shape B x 4 x 2
    def get_coordinate(rec):
        w = rec[:,2]
        # w is only added to the x cooridate
        w = w.repeat(1, 2)
        w[:,1] = 0    
        
        h = rec[:,3]
        # h is only added to th y cooridate
        h = h.repeat(1, 2)
        h[:,0] = 0
        
        top_left = rec[:,0:2]
        top_right = top_left + w
        bottom_left = top_left + h
        bottom_right = bottom_left + w
        
        coords = [top_left, top_right, 
                 bottom_left, bottom_right]
        coords = [v.unsqueeze(dim=1) for v in coords]
        return torch.cat(coords, dim=1)
    
    coord_1 = get_coordinate(rec1)
    print("coordinate 1", coord_1)
    coord_2 = get_coordinate(rec2)
    print("coordindate 2", coord_2)
    
    
    # compute coordinate for the intersection
    left_edge_x = torch.max(coord_1[:,0,0], coord_2[:,0,0])
    print("left_edge_x", left_edge_x)
    right_edge_x = torch.min(coord_1[:,1,0], coord_2[:,1,0])
    print("right_edge_x", right_edge_x)
    top_edge_y = torch.max(coord_1[:,0,1], coord_2[:,0,1])
    print('top_edge_y', top_edge_y)
    bottom_edge_y = torch.min(coord_1[:,2,1], coord_2[:,2,1])
    print('bottom_edge_y', bottom_edge_y)
    
    intersection = (right_edge_x - left_edge_x)*(bottom_edge_y - top_edge_y)
    
    print("intersection is", intersection)
    union = rec1[:,2]*rec1[:,3] + rec2[:,2]*rec2[:,3] - intersection
    
    return float(intersection) / float(union) 

def label_grid(img_dim, grid_scheme):
    '''
    Arg: 
        grid_scheme: how many grids to put on the image
        grid_scheme = (x, y) means one divid the image
        into x * y grids
    
    
    each grid is identified by its index (gx, gy)
    gx means the horizontal index
    gy means the vertical index
    for example: gx=0 and gy=1 means the first grid horizontalwise
    and second grid verticalwise
    
    The value of each grid is a list of dict with keys:
    bbox, object class, area of the grid inside bbox
    '''
    x, y = grid_scheme
    w, h = img_dim
    grid_w = w // x
    grid_h = h // y
    
                
    Grid = {}
    
    # cache more grid info to be used latter
    Grid_ = {} 
    for i in range(grid_w):
        for j in range(grid_h):
            key_ = '{}_{}'.format(i, j)
            Grid[key_] = []
            
            #top left coordinate of the grid
            gx = i*grid_w 
            gy = j*grid_h
            
            Grid[key_] = (gx, gy, grid_w, grid_j)
    
    # for each bbox annotation
    # get the grid that contains its center
    for ann in anns:
        bbox = ann['bbox']
        x, y, xw, yh = bbox
        c_x = x + (xw // 2)
        c_y = y + (yh // 2)
        
        # which grid horizontally contains the center
        gx_idx = c_x // grid_w 
        
        # which grid vertically contains the center
        gy_idx = c_y // grid_h
        
        key_ = '{}_{}'.format(gx_idx, gy_idx)
        Grid[key_].append(
            {
                'bbox': bbox, 
                'class': ann['category_id'],
                'iou': compute_iou(rec1, rec2)
            
            })

# %%
a = torch.Tensor([100, 0, 100, 100]).unsqueeze(0)
b = torch.Tensor([150, 50, 100, 100]).unsqueeze(0)

compute_iou(a,b)
# Out:
# coordinate 1 tensor([[[100.,   0.],
#          [200.,   0.],
#          [100., 100.],
#          [200., 100.]]])
# coordindate 2 tensor([[[150.,  50.],
#          [250.,  50.],
#          [150., 150.],
#          [250., 150.]]])
# left_edge_x tensor([150.])
# right_edge_x tensor([200.])
# top_edge_y tensor([0.])
# bottom_edge_y tensor([150.])
# intersection is tensor([7500.])
# 0.6

# %%
# input img has dimension 640 x 360
# divide the images into 12 x 20, 23x40, 45x80
# grid cells respectively.
# For each grid cell, the network predicts
# center pixel coordinate of a bounding box
# length and height of the bounding box 
# confidence level that the bounding box contains an object
# the object's classes

# the center pixel coordinate is relative to the 
# location of the grid cell, for example if the top left
# corner of the grid cell has absolute coordinate x, y
# then the network predicts the center of the bounding
# box when grid cell is affine tranformed into 
# 0, 0 with length and hight 1



# convert the target to 3 scale bbox dection schemes
# i.e 3 tensors of the shape B x ((5 + Cat)x3) x G x G

img.thumbnail([416,416])
img_ = np.array(img, dtype=np.uint8)
print(img_.shape)
fig, ax = plt.subplots(1)
ax.imshow(img_)


for a in taget:
    
    x,y,x_,y_ = a['bbox']

    x = x * (416 / 640)
    x_ = x_ *(416 / 640)
    y = y * (416 / 360)
    y_ = y_* (416 / 360)
    
    rect = patches.Rectangle((x,y),x_,y_,linewidth=1,
                             edgecolor='r', facecolor='none')
    ax.add_patch(rect)

plt.show()
# Out:
# (234, 416, 3)

# %%
# Out:
# torch.Size([3, 3, 23, 40])
